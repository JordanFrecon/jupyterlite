# %% [markdown]
# <center><img src="attachment:logo.png" style="height:100px"></center>

# %% [markdown]
# <br>
# <center><span style="font-size:35px"><b>Algorithms for Data Analysis</b></span></center>

# %% [markdown]
# <center><span style="font-size:25px"><b>Lab 3: Fundamental Supervised Models | Penguins of Antarctica</b></span></center>
#
# <span style="color:#B667C4">Chinstrap</span>, <span style="color:#347170">Gentoo</span>, and <span style="color:#F07329">Adélie</span> penguins represent a fascinating array of avian species inhabiting the frigid, pristine landscapes of the Southern Hemisphere. These penguins, belonging to the Pygoscelis genus, are renowned for their distinctive characteristics and behaviors, each contributing to the rich tapestry of Antarctic wildlife. The <span style="color:#B667C4">Chinstrap penguin</span> (Pygoscelis antarcticus) sports a distinctive black band under its chin, lending it a striking appearance, while the <span style="color:#347170">Gentoo penguin</span> (Pygoscelis papua) stands out with its vibrant orange beak and captivating waddle. <span style="color:#F07329">Adélie penguins</span> (Pygoscelis adeliae), named after the wife of French explorer Jules Dumont d'Urville, boast a charming charm and are renowned for their agility and adeptness in traversing icy terrains. Together, these penguin species symbolize the resilience and adaptability of Antarctic wildlife in one of the harshest environments on Earth.
#
# ![lter_penguins-2.png](attachment:lter_penguins-2.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.colors as mcolors

# Define the penguins colors
penguins_colors = ['#F07329', '#347170', '#B667C4']

# Define the penguins colormap
color_positions = np.linspace(0, 1, len(penguins_colors))
color_tuples = list(zip(color_positions, penguins_colors))
penguins_cmap = mcolors.LinearSegmentedColormap.from_list("penguins_cmap", color_tuples)

# %% [markdown]
# # 1. Exploratory Data Analysis
#
# Data were collected and made available by Dr. Kristen Gorman and the Palmer Station, Antarctica LTER, a member of the Long Term Ecological Research Network. It has then been cleaned and refactored into the `penguins.csv` file.
#
# > Gorman KB, Williams TD, Fraser WR (2014). Ecological sexual dimorphism and environmental variability within a community of Antarctic penguins (genus Pygoscelis). PLoS ONE 9(3):e90081. https://doi.org/10.1371/journal.pone.0090081
#
#
# ![culmen_depth.png](attachment:culmen_depth.png)

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Use the Panda library to load the dataset into a Pandas serie called ``data``. Then, display and comment the data.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Create a column `species_codes` attributing a number depending on the specie by using scikit-learn function `LabelEncoder`.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Illustrate the probability density function of the *bill length* for each of the specie. Colorize each of them using the appropriate colors (with the keyword `facecolor`) and superpose them with transparency (with the keyword `alpha=0.5`).

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Same question for the *bill depth*.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Which feature representation do you suggest to classify the penguins with respect to their specie. Illustrate your answer.

# %% [markdown]
# # 2. K-Nearest Neighbors Classification

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Define and extract the input $X$ and output data $y$ from the data frame `data`. Make sure to have numpy arrays. What are their shapes?

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Split your dataset $\{X,y\}$ into training, validation and test sets by using `train_test_split` from scikit-learn. Each of them should be 1/3 of the total data. Use the keyword `random_state=42` when splitting (*this way, everyone in the class will have the same splits*).

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Define and train a KNN classifier with 3 neighbors on your training set.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Compare the predicted labels on your validation set with their true labels. Evaluate the validation accuracy of your model.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Investigate the impact of the number of neighbors on the validation accuracy. Plot and comment the curve:<br><center> (x-axis: number of neigbhors, y-axis:validation accuracy).</center>

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Select the optimal number of neighbors.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Now that the hyperparameter (number of neighbors) has been validated. Compute the test error of your model.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> BONUS.** Redo the previous steps but perform k-fold cross validation (see `KFold` from scikit-learn).

# %% [markdown]
# # 3. Competition: Predicting Flipper Length
#
# Your objective is to develop a machine learning model to predict the flipper length of penguins.
# - You have at your disposal the data in `penguins_available.csv`.
# - Your test score should be computed with the data from `penguins_test.csv`. Be careful, it is forbidden to use this data to train or validate your model!
#
# You can freely use...
# - Preprocessing steps (https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing)
# - Data splitting and hyperparameter searches strategies (https://scikit-learn.org/stable/modules/classes.html#module-sklearn.model_selection)
# - Any fundamental model seen in Chapter 3
