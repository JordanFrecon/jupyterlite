# %% [markdown]
# <center><img src="attachment:logo.png" style="height:100px"></center>

# %% [markdown]
# <br>
# <center><span style="font-size:35px"><b>Algorithms for Data Analysis</b></span></center>

# %% [markdown]
# <center><span style="font-size:25px"><b>Lab 5: Neural Networks | Live Camera</b></span></center>
#
# With the proliferation of digital imaging and the rapid advancements in machine learning, understanding how to analyze real-time images and make predictions using trained models has become increasingly important. Through this exercise, you will learn how to capture live images from a webcam, preprocess them for analysis, and utilize multi-layer perceptrons (MLPs) and other supervised learning algorithms to predict labels associated with the captured images. By the end of this exercise, you will have gained valuable insights into applying machine learning techniques to real-world scenarios, laying the foundation for further exploration in computer vision and artificial intelligence
#
# ![jordanfrecondeloire_a_machine_predicting_labels_of_images_captu_3bb05356-d4c5-434a-a861-9b1d330814de-2.png](attachment:jordanfrecondeloire_a_machine_predicting_labels_of_images_captu_3bb05356-d4c5-434a-a861-9b1d330814de-2.png)

# %%
# !pip install opencv-python
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os
from capture import *
from utils import *

# %% [markdown]
# # 1. Data Collection
#
# In this section, you will embark on the initial step of gathering the necessary data for training your machine learning models. Using your webcam, you will capture images in real-time, each resized to a uniform 28x28 pixel resolution. This standardization ensures consistency in the dataset, facilitating effective preprocessing and model training.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Read the help of the function `capture_and_save_images`.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Use the function `capture_and_save_images` to capture multiple images (at least 10) corresponding to the first class. It can be images of yourself, an object, etc. Be creative. Store the corresponding images and labels in variables $X_1$ and $y_1$, respectively.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Same question for the second class. Store the corresponding images and labels in variables $X_2$ and $y_2$, respectively.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Concatenate $X=(X_1,X_2)$ and $y=(y_1,y_2)$. In addition, extract the class names in a variable `class_names`.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Use a label encoder in order to encode target labels `y` with value between 0 and n_classes-1.

# %% [markdown]
# # 2. First Hands on Neural Networks
#
# We are now ready to define and train our first multi-layer perceptron (MLP).

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Define and fit a MLP classifier from the sklearn libary. For now, don't focus too much on its architecture nor its hyper-parameters.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Compare the prediction of the model on $X$ with the true labels `y`. Comment.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Compute the number of parameters of the neural network with the function `count_mlp_parameters`.

# %% [markdown]
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Predict live the label of new samples by resorting to the function `capture_and_predict_labels_live`. Read the help if needed.

# %% [markdown]
# # 3. Challenges

# %% [markdown]
# ## 3.1. Challenge 1: Optimization
#
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Tune the algorithm used for training the MLP in order to obtain the best performing model.

# %% [markdown]
# ## 3.2. Challenge 2: Frugality
#
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Devise the smallest model (i.e., with as few parameters as possible) while still maintaining high prediction performance.

# %% [markdown]
# ## 3.2. Challenge 3: High-Resolution
#
#  **<i class="fa fa-gear fa-spin fa-1x"></i> EXERCISE.** Create a model performing well for high resolution images, i.e., where the arguments `width_pixels` and `height_pixels` passed to capture functions to about 256.
